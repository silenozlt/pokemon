# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
pokemon = pd.read_csv("pokemon.csv")

# %%
pokemon.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon.max()
# Out:
# /var/folders/kp/0ym9rsz906b7vck4b46tb0w40000gn/T/ipykernel_2486/1016419104.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon.max()
# abilities            ['Wonder Skin ', 'Magic Guard', 'Tinted Lens']
# against_bug                                                     4.0
# against_dark                                                    4.0
# against_dragon                                                  2.0
# against_electric                                                4.0
# against_fairy                                                   4.0
# against_fight                                                   4.0
# against_fire                                                    4.0
# against_flying                                                  4.0
# ...

# %%
pokemon.shape
# Out:
# (801, 41)

# %%
pokemon.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
plt.hist(pokemon["type1"],alpha=1, label='Value', color="b",edgecolor="y", linewidth=2,bins=50)
plt.legend()
plt.ylabel('Numbers of Type', size='x-large')
plt.xlabel('Types Name', size= 'x-large')
plt.show()

# %%
sns.barplot(x="is_legendary",y="speed",data=pokemon)
plt.legend()
plt.title("Speed Analysis of Pokemon", size='x-large')
plt.ylabel("Speed of Pokemon", size='large')
plt.xlabel("Legendary of Pokemon", size= 'large')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(x="is_legendary",y="weight_kg",data=pokemon)
plt.legend()
plt.title("Weight Analysis of Pokemon", size='x-large')
plt.ylabel("Weight of Pokemon", size='large')
plt.xlabel("Legendary of Pokemon", size= 'large')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(x="is_legendary",y="speed",palette="rocket",data=pokemon)
plt.legend()
plt.title("7 Generation Analysis of Pokemon", size='x-large')
plt.ylabel('Speed', size='large')
plt.xlabel('Legenday', size= 'large')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(x="is_legendary",y="speed",palette="vlag",data=pokemon) #palette is a colour combination 
plt.legend()
plt.title("7 Generation Analysis of Pokemon", size='x-large')
plt.ylabel('Speed', size='large')
plt.xlabel('Legenday', size= 'large')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.barplot(x="is_legendary",y="speed",hue="generation",data=pokemon)
plt.legend()
plt.title("7 Generation Analysis of Pokemon", size='x-large')
plt.ylabel('Speed', size='large')
plt.xlabel('Legenday', size= 'large')
plt.show()
